# %%
import cv2
import numpy as np
import skimage
from skimage import io
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray
from sklearn import cluster

import matplotlib as plt

import os

# %%
# path for folder containing test x-rays
dataset_path = 'pipeline_outputs/data/validation/'

# adds paths of all files inside of dataset folder
# excludes other folders, directories
file_paths = [f for f in os.listdir(dataset_path) if os.path.isfile(os.path.join(dataset_path, f))]
file_paths = [dataset_path + f for f in file_paths]

file_paths
# Out:
# ['pipeline_outputs/data/validation/9764_PROCESSED.png',
#  'pipeline_outputs/data/validation/10938_PROCESSED.png',
#  'pipeline_outputs/data/validation/10172_PROCESSED.png',
#  'pipeline_outputs/data/validation/10557_PROCESSED.png',
#  'pipeline_outputs/data/validation/10407_PROCESSED.png',
#  'pipeline_outputs/data/validation/13311_PROCESSED.png',
#  'pipeline_outputs/data/validation/13857_PROCESSED.png',
#  'pipeline_outputs/data/validation/15002_PROCESSED.png',
#  'pipeline_outputs/data/validation/13673_PROCESSED.png',
#  'pipeline_outputs/data/validation/14329_PROCESSED.png',
#  'pipeline_outputs/data/validation/10269_PROCESSED.png',
#  'pipeline_outputs/data/validation/10317_PROCESSED.png',
#  'pipeline_outputs/data/validation/11260_PROCESSED.png',
#  'pipeline_outputs/data/validation/11926_PROCESSED.png',
#  'pipeline_outputs/data/validation/11702_PROCESSED.png',
#  'pipeline_outputs/data/validation/9894_PROCESSED.png',
#  'pipeline_outputs/data/validation/14310_PROCESSED.png',
#  'pipeline_outputs/data/validation/12248_PROCESSED.png',
#  'pipeline_outputs/data/validation/12318_PROCESSED.png',
#  'pipeline_outputs/data/validation/10380_PROCESSED.png',
#  'pipeline_outputs/data/validation/11146_PROCESSED.png',
#  'pipeline_outputs/data/validation/11563_PROCESSED.png',
#  'pipeline_outputs/data/validation/13019_PROCESSED.png',
#  'pipeline_outputs/data/validation/11499_PROCESSED.png',
#  'pipeline_outputs/data/validation/13903_PROCESSED.png',
#  'pipeline_outputs/data/validation/15489_PROCESSED.png',
#  'pipeline_outputs/data/validation/12083_PROCESSED.png',
#  'pipeline_outputs/data/validation/12262_PROCESSED.png',
#  'pipeline_outputs/data/validation/10553_PROCESSED.png',
#  'pipeline_outputs/data/validation/14387_PROCESSED.png',
#  'pipeline_outputs/data/validation/9760_PROCESSED.png',
#  'pipeline_outputs/data/validation/14731_PROCESSED.png',
#  'pipeline_outputs/data/validation/13542_PROCESSED.png',
#  'pipeline_outputs/data/validation/13386_PROCESSED.png',
#  'pipeline_outputs/data/validation/15082_PROCESSED.png',
#  'pipeline_outputs/data/validation/13659_PROCESSED.png',
#  'pipeline_outputs/data/validation/10349_PROCESSED.png',
#  'pipeline_outputs/data/validation/13960_PROCESSED.png',
#  'pipeline_outputs/data/validation/15507_PROCESSED.png',
#  'pipeline_outputs/data/validation/11895_PROCESSED.png',
#  'pipeline_outputs/data/validation/11125_PROCESSED.png',
#  'pipeline_outputs/data/validation/14112_PROCESSED.png',
#  'pipeline_outputs/data/validation/12368_PROCESSED.png',
#  'pipeline_outputs/data/validation/14181_PROCESSED.png',
#  'pipeline_outputs/data/validation/14230_PROCESSED.png',
#  'pipeline_outputs/data/validation/10966_PROCESSED.png',
#  'pipeline_outputs/data/validation/14519_PROCESSED.png',
#  'pipeline_outputs/data/validation/10191_PROCESSED.png',
#  'pipeline_outputs/data/validation/12134_PROCESSED.png',
#  'pipeline_outputs/data/validation/11357_PROCESSED.png',
#  'pipeline_outputs/data/validation/15217_PROCESSED.png',
#  'pipeline_outputs/data/validation/15200_PROCESSED.png',
#  'pipeline_outputs/data/validation/12839_PROCESSED.png',
#  'pipeline_outputs/data/validation/14602_PROCESSED.png',
#  'pipeline_outputs/data/validation/14116_PROCESSED.png',
#  'pipeline_outputs/data/validation/10473_PROCESSED.png',
#  'pipeline_outputs/data/validation/12637_PROCESSED.png',
#  'pipeline_outputs/data/validation/13235_PROCESSED.png',
#  'pipeline_outputs/data/validation/13288_PROCESSED.png',
#  'pipeline_outputs/data/validation/15280_PROCESSED.png',
#  'pipeline_outputs/data/validation/11608_PROCESSED.png',
#  'pipeline_outputs/data/validation/11886_PROCESSED.png',
#  'pipeline_outputs/data/validation/15076_PROCESSED.png',
#  'pipeline_outputs/data/validation/13757_PROCESSED.png',
#  'pipeline_outputs/data/validation/11136_PROCESSED.png',
#  'pipeline_outputs/data/validation/14695_PROCESSED.png',
#  'pipeline_outputs/data/validation/14888_PROCESSED.png',
#  'pipeline_outputs/data/validation/14756_PROCESSED.png',
#  'pipeline_outputs/data/validation/12127_PROCESSED.png',
#  'pipeline_outputs/data/validation/15058_PROCESSED.png',
#  'pipeline_outputs/data/validation/13525_PROCESSED.png',
#  'pipeline_outputs/data/validation/13475_PROCESSED.png',
#  'pipeline_outputs/data/validation/15590_PROCESSED.png',
#  'pipeline_outputs/data/validation/14068_PROCESSED.png',
#  'pipeline_outputs/data/validation/10601_PROCESSED.png',
#  'pipeline_outputs/data/validation/14185_PROCESSED.png',
#  'pipeline_outputs/data/validation/10832_PROCESSED.png',
#  'pipeline_outputs/data/validation/14611_PROCESSED.png',
#  'pipeline_outputs/data/validation/14111_PROCESSED.png',
#  'pipeline_outputs/data/validation/10778_PROCESSED.png',
#  'pipeline_outputs/data/validation/10101_PROCESSED.png',
#  'pipeline_outputs/data/validation/12215_PROCESSED.png',
#  'pipeline_outputs/data/validation/10695_PROCESSED.png',
#  'pipeline_outputs/data/validation/11076_PROCESSED.png',
#  'pipeline_outputs/data/validation/11297_PROCESSED.png',
#  'pipeline_outputs/data/validation/15504_PROCESSED.png',
#  'pipeline_outputs/data/validation/11131_PROCESSED.png',
#  'pipeline_outputs/data/validation/12814_PROCESSED.png',
#  'pipeline_outputs/data/validation/12944_PROCESSED.png',
#  'pipeline_outputs/data/validation/10822_PROCESSED.png',
#  'pipeline_outputs/data/validation/10611_PROCESSED.png',
#  'pipeline_outputs/data/validation/12120_PROCESSED.png',
#  'pipeline_outputs/data/validation/11766_PROCESSED.png',
#  'pipeline_outputs/data/validation/11955_PROCESSED.png',
#  'pipeline_outputs/data/validation/13769_PROCESSED.png',
#  'pipeline_outputs/data/validation/13535_PROCESSED.png',
#  'pipeline_outputs/data/validation/14746_PROCESSED.png',
#  'pipeline_outputs/data/validation/14052_PROCESSED.png',
#  'pipeline_outputs/data/validation/14948_PROCESSED.png',
#  'pipeline_outputs/data/validation/12773_PROCESSED.png',
#  'pipeline_outputs/data/validation/10467_PROCESSED.png',
#  'pipeline_outputs/data/validation/10686_PROCESSED.png',
#  'pipeline_outputs/data/validation/10808_PROCESSED.png',
#  'pipeline_outputs/data/validation/10958_PROCESSED.png',
#  'pipeline_outputs/data/validation/11284_PROCESSED.png',
#  'pipeline_outputs/data/validation/15075_PROCESSED.png',
#  'pipeline_outputs/data/validation/15125_PROCESSED.png',
#  'pipeline_outputs/data/validation/11188_PROCESSED.png',
#  'pipeline_outputs/data/validation/11122_PROCESSED.png',
#  'pipeline_outputs/data/validation/11457_PROCESSED.png',
#  'pipeline_outputs/data/validation/13613_PROCESSED.png',
#  'pipeline_outputs/data/validation/12634_PROCESSED.png',
#  'pipeline_outputs/data/validation/14219_PROCESSED.png',
#  'pipeline_outputs/data/validation/10359_PROCESSED.png',
#  'pipeline_outputs/data/validation/12468_PROCESSED.png',
#  'pipeline_outputs/data/validation/14612_PROCESSED.png',
#  'pipeline_outputs/data/validation/14971_PROCESSED.png',
#  'pipeline_outputs/data/validation/10752_PROCESSED.png',
#  'pipeline_outputs/data/validation/14821_PROCESSED.png',
#  'pipeline_outputs/data/validation/15539_PROCESSED.png',
#  'pipeline_outputs/data/validation/11350_PROCESSED.png',
#  'pipeline_outputs/data/validation/11632_PROCESSED.png',
#  'pipeline_outputs/data/validation/13103_PROCESSED.png',
#  'pipeline_outputs/data/validation/14459_PROCESSED.png',
#  'pipeline_outputs/data/validation/12228_PROCESSED.png',
#  'pipeline_outputs/data/validation/12378_PROCESSED.png',
#  'pipeline_outputs/data/validation/10991_PROCESSED.png',
#  'pipeline_outputs/data/validation/10543_PROCESSED.png',
#  'pipeline_outputs/data/validation/11434_PROCESSED.png',
#  'pipeline_outputs/data/validation/11489_PROCESSED.png',
#  'pipeline_outputs/data/validation/11792_PROCESSED.png',
#  'pipeline_outputs/data/validation/11573_PROCESSED.png',
#  'pipeline_outputs/data/validation/11156_PROCESSED.png',
#  'pipeline_outputs/data/validation/13242_PROCESSED.png',
#  'pipeline_outputs/data/validation/14718_PROCESSED.png',
#  'pipeline_outputs/data/validation/12147_PROCESSED.png',
#  'pipeline_outputs/data/validation/12783_PROCESSED.png',
#  'pipeline_outputs/data/validation/10497_PROCESSED.png',
#  'pipeline_outputs/data/validation/11274_PROCESSED.png',
#  'pipeline_outputs/data/validation/13545_PROCESSED.png',
#  'pipeline_outputs/data/validation/13415_PROCESSED.png',
#  'pipeline_outputs/data/validation/15264_PROCESSED.png',
#  'pipeline_outputs/data/validation/11178_PROCESSED.png',
#  'pipeline_outputs/data/validation/11028_PROCESSED.png',
#  'pipeline_outputs/data/validation/11333_PROCESSED.png',
#  'pipeline_outputs/data/validation/12425_PROCESSED.png',
#  'pipeline_outputs/data/validation/14158_PROCESSED.png',
#  'pipeline_outputs/data/validation/9880_PROCESSED.png',
#  'pipeline_outputs/data/validation/10018_PROCESSED.png',
#  'pipeline_outputs/data/validation/12679_PROCESSED.png',
#  'pipeline_outputs/data/validation/12877_PROCESSED.png',
#  'pipeline_outputs/data/validation/14540_PROCESSED.png',
#  'pipeline_outputs/data/validation/10098_PROCESSED.png',
#  'pipeline_outputs/data/validation/14088_PROCESSED.png',
#  'pipeline_outputs/data/validation/12644_PROCESSED.png',
#  'pipeline_outputs/data/validation/11796_PROCESSED.png',
#  'pipeline_outputs/data/validation/13724_PROCESSED.png',
#  'pipeline_outputs/data/validation/13301_PROCESSED.png',
#  'pipeline_outputs/data/validation/12653_PROCESSED.png',
#  'pipeline_outputs/data/validation/10162_PROCESSED.png',
#  'pipeline_outputs/data/validation/12326_PROCESSED.png',
#  'pipeline_outputs/data/validation/10032_PROCESSED.png',
#  'pipeline_outputs/data/validation/14393_PROCESSED.png',
#  'pipeline_outputs/data/validation/14725_PROCESSED.png',
#  'pipeline_outputs/data/validation/9839_PROCESSED.png',
#  'pipeline_outputs/data/validation/10569_PROCESSED.png',
#  'pipeline_outputs/data/validation/12790_PROCESSED.png',
#  'pipeline_outputs/data/validation/11337_PROCESSED.png',
#  'pipeline_outputs/data/validation/11871_PROCESSED.png',
#  'pipeline_outputs/data/validation/11921_PROCESSED.png',
#  'pipeline_outputs/data/validation/13268_PROCESSED.png',
#  'pipeline_outputs/data/validation/11559_PROCESSED.png',
#  'pipeline_outputs/data/validation/11270_PROCESSED.png',
#  'pipeline_outputs/data/validation/13411_PROCESSED.png',
#  'pipeline_outputs/data/validation/12909_PROCESSED.png',
#  'pipeline_outputs/data/validation/14662_PROCESSED.png',
#  'pipeline_outputs/data/validation/14028_PROCESSED.png',
#  'pipeline_outputs/data/validation/10711_PROCESSED.png',
#  'pipeline_outputs/data/validation/14701_PROCESSED.png',
#  'pipeline_outputs/data/validation/10389_PROCESSED.png',
#  'pipeline_outputs/data/validation/9769_PROCESSED.png',
#  'pipeline_outputs/data/validation/10795_PROCESSED.png',
#  'pipeline_outputs/data/validation/12903_PROCESSED.png',
#  'pipeline_outputs/data/validation/14564_PROCESSED.png',
#  'pipeline_outputs/data/validation/14785_PROCESSED.png',
#  'pipeline_outputs/data/validation/13332_PROCESSED.png',
#  'pipeline_outputs/data/validation/13262_PROCESSED.png',
#  'pipeline_outputs/data/validation/11403_PROCESSED.png',
#  'pipeline_outputs/data/validation/11553_PROCESSED.png',
#  'pipeline_outputs/data/validation/11161_PROCESSED.png',
#  'pipeline_outputs/data/validation/13275_PROCESSED.png',
#  'pipeline_outputs/data/validation/11031_PROCESSED.png',
#  'pipeline_outputs/data/validation/13650_PROCESSED.png',
#  'pipeline_outputs/data/validation/11544_PROCESSED.png',
#  'pipeline_outputs/data/validation/15554_PROCESSED.png',
#  'pipeline_outputs/data/validation/15390_PROCESSED.png',
#  'pipeline_outputs/data/validation/14573_PROCESSED.png',
#  'pipeline_outputs/data/validation/12844_PROCESSED.png',
#  'pipeline_outputs/data/validation/14792_PROCESSED.png',
#  'pipeline_outputs/data/validation/11429_PROCESSED.png',
#  'pipeline_outputs/data/validation/13318_PROCESSED.png',
#  'pipeline_outputs/data/validation/11846_PROCESSED.png',
#  'pipeline_outputs/data/validation/13576_PROCESSED.png',
#  'pipeline_outputs/data/validation/10549_PROCESSED.png',
#  'pipeline_outputs/data/validation/14655_PROCESSED.png',
#  'pipeline_outputs/data/validation/14320_PROCESSED.png',
#  'pipeline_outputs/data/validation/12395_PROCESSED.png',
#  'pipeline_outputs/data/validation/10142_PROCESSED.png',
#  'pipeline_outputs/data/validation/12256_PROCESSED.png',
#  'pipeline_outputs/data/validation/15400_PROCESSED.png',
#  'pipeline_outputs/data/validation/15394_PROCESSED.png',
#  'pipeline_outputs/data/validation/13558_PROCESSED.png',
#  'pipeline_outputs/data/validation/11384_PROCESSED.png',
#  'pipeline_outputs/data/validation/13090_PROCESSED.png',
#  'pipeline_outputs/data/validation/15547_PROCESSED.png',
#  'pipeline_outputs/data/validation/11985_PROCESSED.png',
#  'pipeline_outputs/data/validation/9743_PROCESSED.png',
#  'pipeline_outputs/data/validation/12117_PROCESSED.png',
#  'pipeline_outputs/data/validation/14636_PROCESSED.png',
#  'pipeline_outputs/data/validation/15611_PROCESSED.png',
#  'pipeline_outputs/data/validation/15068_PROCESSED.png',
#  'pipeline_outputs/data/validation/13281_PROCESSED.png',
#  'pipeline_outputs/data/validation/13127_PROCESSED.png',
#  'pipeline_outputs/data/validation/13296_PROCESSED.png',
#  'pipeline_outputs/data/validation/10344_PROCESSED.png',
#  'pipeline_outputs/data/validation/14108_PROCESSED.png',
#  'pipeline_outputs/data/validation/9980_PROCESSED.png',
#  'pipeline_outputs/data/validation/13109_PROCESSED.png',
#  'pipeline_outputs/data/validation/13059_PROCESSED.png',
#  'pipeline_outputs/data/validation/15474_PROCESSED.png',
#  'pipeline_outputs/data/validation/15101_PROCESSED.png',
#  'pipeline_outputs/data/validation/11692_PROCESSED.png',
#  'pipeline_outputs/data/validation/15046_PROCESSED.png',
#  'pipeline_outputs/data/validation/12823_PROCESSED.png',
#  'pipeline_outputs/data/validation/12365_PROCESSED.png',
#  'pipeline_outputs/data/validation/12471_PROCESSED.png',
#  'pipeline_outputs/data/validation/11821_PROCESSED.png',
#  'pipeline_outputs/data/validation/11370_PROCESSED.png',
#  'pipeline_outputs/data/validation/13238_PROCESSED.png',
#  'pipeline_outputs/data/validation/14583_PROCESSED.png',
#  'pipeline_outputs/data/validation/12113_PROCESSED.png',
#  'pipeline_outputs/data/validation/10622_PROCESSED.png',
#  'pipeline_outputs/data/validation/10772_PROCESSED.png',
#  'pipeline_outputs/data/validation/10593_PROCESSED.png',
#  'pipeline_outputs/data/validation/14892_PROCESSED.png',
#  'pipeline_outputs/data/validation/12977_PROCESSED.png',
#  'pipeline_outputs/data/validation/15042_PROCESSED.png',
#  'pipeline_outputs/data/validation/11948_PROCESSED.png',
#  'pipeline_outputs/data/validation/13774_PROCESSED.png',
#  'pipeline_outputs/data/validation/13478_PROCESSED.png',
#  'pipeline_outputs/data/validation/15055_PROCESSED.png',
#  'pipeline_outputs/data/validation/14457_PROCESSED.png',
#  'pipeline_outputs/data/validation/10283_PROCESSED.png',
#  'pipeline_outputs/data/validation/12526_PROCESSED.png',
#  'pipeline_outputs/data/validation/9983_PROCESSED.png',
#  'pipeline_outputs/data/validation/14207_PROCESSED.png',
#  'pipeline_outputs/data/validation/11976_PROCESSED.png',
#  'pipeline_outputs/data/validation/15370_PROCESSED.png',
#  'pipeline_outputs/data/validation/11745_PROCESSED.png',
#  'pipeline_outputs/data/validation/13829_PROCESSED.png',
#  'pipeline_outputs/data/validation/11831_PROCESSED.png',
#  'pipeline_outputs/data/validation/15612_PROCESSED.png',
#  'pipeline_outputs/data/validation/14210_PROCESSED.png',
#  'pipeline_outputs/data/validation/14956_PROCESSED.png',
#  'pipeline_outputs/data/validation/10350_PROCESSED.png',
#  'pipeline_outputs/data/validation/10072_PROCESSED.png',
#  'pipeline_outputs/data/validation/10507_PROCESSED.png',
#  'pipeline_outputs/data/validation/11359_PROCESSED.png',
#  'pipeline_outputs/data/validation/13468_PROCESSED.png',
#  'pipeline_outputs/data/validation/15219_PROCESSED.png',
#  'pipeline_outputs/data/validation/13585_PROCESSED.png',
#  'pipeline_outputs/data/validation/15349_PROCESSED.png',
#  'pipeline_outputs/data/validation/11520_PROCESSED.png',
#  'pipeline_outputs/data/validation/15477_PROCESSED.png',
#  'pipeline_outputs/data/validation/13940_PROCESSED.png',
#  'pipeline_outputs/data/validation/12508_PROCESSED.png',
#  'pipeline_outputs/data/validation/10135_PROCESSED.png',
#  'pipeline_outputs/data/validation/10065_PROCESSED.png',
#  'pipeline_outputs/data/validation/12221_PROCESSED.png',
#  'pipeline_outputs/data/validation/12110_PROCESSED.png',
#  'pipeline_outputs/data/validation/14580_PROCESSED.png',
#  'pipeline_outputs/data/validation/15182_PROCESSED.png',
#  'pipeline_outputs/data/validation/15601_PROCESSED.png',
#  'pipeline_outputs/data/validation/13759_PROCESSED.png',
#  'pipeline_outputs/data/validation/10805_PROCESSED.png',
#  'pipeline_outputs/data/validation/14203_PROCESSED.png',
#  'pipeline_outputs/data/validation/12472_PROCESSED.png',
#  'pipeline_outputs/data/validation/10213_PROCESSED.png',
#  'pipeline_outputs/data/validation/10587_PROCESSED.png',
#  'pipeline_outputs/data/validation/14290_PROCESSED.png',
#  'pipeline_outputs/data/validation/9727_PROCESSED.png',
#  'pipeline_outputs/data/validation/12963_PROCESSED.png',
#  'pipeline_outputs/data/validation/13944_PROCESSED.png',
#  'pipeline_outputs/data/validation/13627_PROCESSED.png',
#  'pipeline_outputs/data/validation/13345_PROCESSED.png',
#  'pipeline_outputs/data/validation/11599_PROCESSED.png',
#  'pipeline_outputs/data/validation/12183_PROCESSED.png',
#  'pipeline_outputs/data/validation/10409_PROCESSED.png',
#  'pipeline_outputs/data/validation/11493_PROCESSED.png',
#  'pipeline_outputs/data/validation/13308_PROCESSED.png',
#  'pipeline_outputs/data/validation/15494_PROCESSED.png',
#  'pipeline_outputs/data/validation/10921_PROCESSED.png',
#  'pipeline_outputs/data/validation/12406_PROCESSED.png',
#  'pipeline_outputs/data/validation/10560_PROCESSED.png',
#  'pipeline_outputs/data/validation/12674_PROCESSED.png',
#  'pipeline_outputs/data/validation/12428_PROCESSED.png',
#  'pipeline_outputs/data/validation/14791_PROCESSED.png',
#  'pipeline_outputs/data/validation/13644_PROCESSED.png',
#  'pipeline_outputs/data/validation/13877_PROCESSED.png',
#  'pipeline_outputs/data/validation/10082_PROCESSED.png',
#  'pipeline_outputs/data/validation/10263_PROCESSED.png',
#  'pipeline_outputs/data/validation/13794_PROCESSED.png',
#  'pipeline_outputs/data/validation/13150_PROCESSED.png',
#  'pipeline_outputs/data/validation/11497_PROCESSED.png',
#  'pipeline_outputs/data/validation/13432_PROCESSED.png',
#  'pipeline_outputs/data/validation/10028_PROCESSED.png',
#  'pipeline_outputs/data/validation/12381_PROCESSED.png',
#  'pipeline_outputs/data/validation/12242_PROCESSED.png',
#  'pipeline_outputs/data/validation/9973_PROCESSED.png',
#  'pipeline_outputs/data/validation/10792_PROCESSED.png',
#  'pipeline_outputs/data/validation/13864_PROCESSED.png',
#  'pipeline_outputs/data/validation/12843_PROCESSED.png',
#  'pipeline_outputs/data/validation/14001_PROCESSED.png',
#  'pipeline_outputs/data/validation/9757_PROCESSED.png',
#  'pipeline_outputs/data/validation/14678_PROCESSED.png',
#  'pipeline_outputs/data/validation/15535_PROCESSED.png',
#  'pipeline_outputs/data/validation/11694_PROCESSED.png',
#  'pipeline_outputs/data/validation/10127_PROCESSED.png',
#  'pipeline_outputs/data/validation/9731_PROCESSED.png',
#  'pipeline_outputs/data/validation/14070_PROCESSED.png',
#  'pipeline_outputs/data/validation/14887_PROCESSED.png',
#  'pipeline_outputs/data/validation/12195_PROCESSED.png',
#  'pipeline_outputs/data/validation/14609_PROCESSED.png',
#  'pipeline_outputs/data/validation/10515_PROCESSED.png',
#  'pipeline_outputs/data/validation/10445_PROCESSED.png',
#  'pipeline_outputs/data/validation/11047_PROCESSED.png',
#  'pipeline_outputs/data/validation/13945_PROCESSED.png',
#  'pipeline_outputs/data/validation/11288_PROCESSED.png',
#  'pipeline_outputs/data/validation/11069_PROCESSED.png',
#  'pipeline_outputs/data/validation/13121_PROCESSED.png',
#  'pipeline_outputs/data/validation/10804_PROCESSED.png',
#  'pipeline_outputs/data/validation/10620_PROCESSED.png',
#  'pipeline_outputs/data/validation/10770_PROCESSED.png',
#  'pipeline_outputs/data/validation/10355_PROCESSED.png',
#  'pipeline_outputs/data/validation/13513_PROCESSED.png',
#  'pipeline_outputs/data/validation/11834_PROCESSED.png',
#  'pipeline_outputs/data/validation/14378_PROCESSED.png',
#  'pipeline_outputs/data/validation/12605_PROCESSED.png',
#  'pipeline_outputs/data/validation/14199_PROCESSED.png',
#  'pipeline_outputs/data/validation/10189_PROCESSED.png',
#  'pipeline_outputs/data/validation/12966_PROCESSED.png',
#  'pipeline_outputs/data/validation/13584_PROCESSED.png',
#  'pipeline_outputs/data/validation/13210_PROCESSED.png',
#  'pipeline_outputs/data/validation/13469_PROCESSED.png',
#  'pipeline_outputs/data/validation/13688_PROCESSED.png',
#  'pipeline_outputs/data/validation/13806_PROCESSED.png',
#  'pipeline_outputs/data/validation/15366_PROCESSED.png',
#  'pipeline_outputs/data/validation/13978_PROCESSED.png',
#  'pipeline_outputs/data/validation/14807_PROCESSED.png',
#  'pipeline_outputs/data/validation/10817_PROCESSED.png',
#  'pipeline_outputs/data/validation/14764_PROCESSED.png',
#  'pipeline_outputs/data/validation/14341_PROCESSED.png',
#  'pipeline_outputs/data/validation/11518_PROCESSED.png',
#  'pipeline_outputs/data/validation/13882_PROCESSED.png',
#  'pipeline_outputs/data/validation/10565_PROCESSED.png',
#  'pipeline_outputs/data/validation/14498_PROCESSED.png',
#  'pipeline_outputs/data/validation/14000_PROCESSED.png',
#  'pipeline_outputs/data/validation/14150_PROCESSED.png',
#  'pipeline_outputs/data/validation/11555_PROCESSED.png',
#  'pipeline_outputs/data/validation/13711_PROCESSED.png',
#  'pipeline_outputs/data/validation/11391_PROCESSED.png',
#  'pipeline_outputs/data/validation/13085_PROCESSED.png',
#  'pipeline_outputs/data/validation/11659_PROCESSED.png',
#  'pipeline_outputs/data/validation/14335_PROCESSED.png',
#  'pipeline_outputs/data/validation/14272_PROCESSED.png',
#  'pipeline_outputs/data/validation/10924_PROCESSED.png',
#  'pipeline_outputs/data/validation/15305_PROCESSED.png',
#  'pipeline_outputs/data/validation/11903_PROCESSED.png',
#  'pipeline_outputs/data/validation/12851_PROCESSED.png',
#  'pipeline_outputs/data/validation/12429_PROCESSED.png',
#  'pipeline_outputs/data/validation/12725_PROCESSED.png',
#  'pipeline_outputs/data/validation/9961_PROCESSED.png',
#  'pipeline_outputs/data/validation/12494_PROCESSED.png',
#  'pipeline_outputs/data/validation/13277_PROCESSED.png',
#  'pipeline_outputs/data/validation/11994_PROCESSED.png',
#  'pipeline_outputs/data/validation/11438_PROCESSED.png',
#  'pipeline_outputs/data/validation/15428_PROCESSED.png',
#  'pipeline_outputs/data/validation/13570_PROCESSED.png',
#  'pipeline_outputs/data/validation/12868_PROCESSED.png',
#  'pipeline_outputs/data/validation/14097_PROCESSED.png',
#  'pipeline_outputs/data/validation/12992_PROCESSED.png',
#  'pipeline_outputs/data/validation/14548_PROCESSED.png',
#  'pipeline_outputs/data/validation/12165_PROCESSED.png',
#  'pipeline_outputs/data/validation/13142_PROCESSED.png',
#  'pipeline_outputs/data/validation/13437_PROCESSED.png',
#  'pipeline_outputs/data/validation/13871_PROCESSED.png',
#  'pipeline_outputs/data/validation/13337_PROCESSED.png',
#  'pipeline_outputs/data/validation/11869_PROCESSED.png',
#  'pipeline_outputs/data/validation/11392_PROCESSED.png',
#  'pipeline_outputs/data/validation/9821_PROCESSED.png',
#  'pipeline_outputs/data/validation/14318_PROCESSED.png',
#  'pipeline_outputs/data/validation/9755_PROCESSED.png',
#  'pipeline_outputs/data/validation/12307_PROCESSED.png',
#  'pipeline_outputs/data/validation/11541_PROCESSED.png',
#  'pipeline_outputs/data/validation/15551_PROCESSED.png',
#  'pipeline_outputs/data/validation/15256_PROCESSED.png',
#  'pipeline_outputs/data/validation/11482_PROCESSED.png',
#  'pipeline_outputs/data/validation/13577_PROCESSED.png',
#  'pipeline_outputs/data/validation/13002_PROCESSED.png',
#  'pipeline_outputs/data/validation/14937_PROCESSED.png',
#  'pipeline_outputs/data/validation/12400_PROCESSED.png',
#  'pipeline_outputs/data/validation/12928_PROCESSED.png',
#  'pipeline_outputs/data/validation/10703_PROCESSED.png',
#  'pipeline_outputs/data/validation/15568_PROCESSED.png',
#  'pipeline_outputs/data/validation/11251_PROCESSED.png',
#  'pipeline_outputs/data/validation/11030_PROCESSED.png',
#  'pipeline_outputs/data/validation/9832_PROCESSED.png',
#  'pipeline_outputs/data/validation/10432_PROCESSED.png',
#  'pipeline_outputs/data/validation/12661_PROCESSED.png',
#  'pipeline_outputs/data/validation/13263_PROCESSED.png',
#  'pipeline_outputs/data/validation/11009_PROCESSED.png',
#  'pipeline_outputs/data/validation/13785_PROCESSED.png',
#  'pipeline_outputs/data/validation/13141_PROCESSED.png',
#  'pipeline_outputs/data/validation/10934_PROCESSED.png',
#  'pipeline_outputs/data/validation/12708_PROCESSED.png',
#  'pipeline_outputs/data/validation/14650_PROCESSED.png',
#  'pipeline_outputs/data/validation/10923_PROCESSED.png',
#  'pipeline_outputs/data/validation/14325_PROCESSED.png',
#  'pipeline_outputs/data/validation/12390_PROCESSED.png',
#  'pipeline_outputs/data/validation/12404_PROCESSED.png',
#  'pipeline_outputs/data/validation/11312_PROCESSED.png',
#  'pipeline_outputs/data/validation/11218_PROCESSED.png',
#  'pipeline_outputs/data/validation/15521_PROCESSED.png',
#  'pipeline_outputs/data/validation/13946_PROCESSED.png',
#  'pipeline_outputs/data/validation/11680_PROCESSED.png',
#  'pipeline_outputs/data/validation/11461_PROCESSED.png',
#  'pipeline_outputs/data/validation/11531_PROCESSED.png',
#  'pipeline_outputs/data/validation/13200_PROCESSED.png',
#  'pipeline_outputs/data/validation/10516_PROCESSED.png',
#  'pipeline_outputs/data/validation/12377_PROCESSED.png',
#  'pipeline_outputs/data/validation/10133_PROCESSED.png',
#  'pipeline_outputs/data/validation/12961_PROCESSED.png',
#  'pipeline_outputs/data/validation/14506_PROCESSED.png',
#  'pipeline_outputs/data/validation/10295_PROCESSED.png',
#  'pipeline_outputs/data/validation/14893_PROCESSED.png',
#  'pipeline_outputs/data/validation/10124_PROCESSED.png',
#  'pipeline_outputs/data/validation/13632_PROCESSED.png',
#  'pipeline_outputs/data/validation/13762_PROCESSED.png',
#  'pipeline_outputs/data/validation/15466_PROCESSED.png',
#  'pipeline_outputs/data/validation/11967_PROCESSED.png',
#  'pipeline_outputs/data/validation/13892_PROCESSED.png',
#  'pipeline_outputs/data/validation/11221_PROCESSED.png',
#  'pipeline_outputs/data/validation/15448_PROCESSED.png',
#  'pipeline_outputs/data/validation/13284_PROCESSED.png',
#  'pipeline_outputs/data/validation/12112_PROCESSED.png',
#  'pipeline_outputs/data/validation/14201_PROCESSED.png',
#  'pipeline_outputs/data/validation/14774_PROCESSED.png',
#  'pipeline_outputs/data/validation/14528_PROCESSED.png',
#  'pipeline_outputs/data/validation/13587_PROCESSED.png',
#  'pipeline_outputs/data/validation/13213_PROCESSED.png',
#  'pipeline_outputs/data/validation/12185_PROCESSED.png',
#  'pipeline_outputs/data/validation/14897_PROCESSED.png',
#  'pipeline_outputs/data/validation/12068_PROCESSED.png',
#  'pipeline_outputs/data/validation/12606_PROCESSED.png',
#  'pipeline_outputs/data/validation/11684_PROCESSED.png',
#  'pipeline_outputs/data/validation/11535_PROCESSED.png',
#  'pipeline_outputs/data/validation/13621_PROCESSED.png',
#  'pipeline_outputs/data/validation/13354_PROCESSED.png',
#  'pipeline_outputs/data/validation/15607_PROCESSED.png',
#  'pipeline_outputs/data/validation/11183_PROCESSED.png',
#  'pipeline_outputs/data/validation/10215_PROCESSED.png',
#  'pipeline_outputs/data/validation/10630_PROCESSED.png',
#  'pipeline_outputs/data/validation/12695_PROCESSED.png',
#  'pipeline_outputs/data/validation/14355_PROCESSED.png',
#  'pipeline_outputs/data/validation/10119_PROCESSED.png',
#  'pipeline_outputs/data/validation/14767_PROCESSED.png',
#  'pipeline_outputs/data/validation/12463_PROCESSED.png',
#  'pipeline_outputs/data/validation/10596_PROCESSED.png',
#  'pipeline_outputs/data/validation/11600_PROCESSED.png',
#  'pipeline_outputs/data/validation/15184_PROCESSED.png',
#  'pipeline_outputs/data/validation/13477_PROCESSED.png',
#  'pipeline_outputs/data/validation/15592_PROCESSED.png',
#  'pipeline_outputs/data/validation/11950_PROCESSED.png',
#  'pipeline_outputs/data/validation/10448_PROCESSED.png',
#  'pipeline_outputs/data/validation/9848_PROCESSED.png',
#  'pipeline_outputs/data/validation/14221_PROCESSED.png',
#  'pipeline_outputs/data/validation/10744_PROCESSED.png',
#  'pipeline_outputs/data/validation/12132_PROCESSED.png',
#  'pipeline_outputs/data/validation/14187_PROCESSED.png',
#  'pipeline_outputs/data/validation/14236_PROCESSED.png',
#  'pipeline_outputs/data/validation/11774_PROCESSED.png',
#  'pipeline_outputs/data/validation/11506_PROCESSED.png',
#  'pipeline_outputs/data/validation/11839_PROCESSED.png',
#  'pipeline_outputs/data/validation/11884_PROCESSED.png',
#  'pipeline_outputs/data/validation/12956_PROCESSED.png',
#  'pipeline_outputs/data/validation/12806_PROCESSED.png',
#  'pipeline_outputs/data/validation/9921_PROCESSED.png',
#  'pipeline_outputs/data/validation/14218_PROCESSED.png',
#  'pipeline_outputs/data/validation/10959_PROCESSED.png',
#  'pipeline_outputs/data/validation/13836_PROCESSED.png',
#  'pipeline_outputs/data/validation/11238_PROCESSED.png',
#  'pipeline_outputs/data/validation/11511_PROCESSED.png',
#  'pipeline_outputs/data/validation/15049_PROCESSED.png',
#  'pipeline_outputs/data/validation/11109_PROCESSED.png',
#  'pipeline_outputs/data/validation/11943_PROCESSED.png',
#  'pipeline_outputs/data/validation/10193_PROCESSED.png',
#  'pipeline_outputs/data/validation/14974_PROCESSED.png',
#  'pipeline_outputs/data/validation/12066_PROCESSED.png',
#  'pipeline_outputs/data/validation/12071_PROCESSED.png',
#  'pipeline_outputs/data/validation/10365_PROCESSED.png',
#  'pipeline_outputs/data/validation/11954_PROCESSED.png',
#  'pipeline_outputs/data/validation/13473_PROCESSED.png',
#  'pipeline_outputs/data/validation/11767_PROCESSED.png',
#  'pipeline_outputs/data/validation/13374_PROCESSED.png',
#  'pipeline_outputs/data/validation/13751_PROCESSED.png',
#  'pipeline_outputs/data/validation/11515_PROCESSED.png',
#  'pipeline_outputs/data/validation/13299_PROCESSED.png',
#  'pipeline_outputs/data/validation/12815_PROCESSED.png',
#  'pipeline_outputs/data/validation/10050_PROCESSED.png',
#  'pipeline_outputs/data/validation/11296_PROCESSED.png',
#  'pipeline_outputs/data/validation/11271_PROCESSED.png',
#  'pipeline_outputs/data/validation/11090_PROCESSED.png',
#  'pipeline_outputs/data/validation/10840_PROCESSED.png',
#  'pipeline_outputs/data/validation/12142_PROCESSED.png',
#  'pipeline_outputs/data/validation/12858_PROCESSED.png',
#  'pipeline_outputs/data/validation/10241_PROCESSED.png',
#  'pipeline_outputs/data/validation/9885_PROCESSED.png',
#  'pipeline_outputs/data/validation/14578_PROCESSED.png',
#  'pipeline_outputs/data/validation/9838_PROCESSED.png',
#  'pipeline_outputs/data/validation/14495_PROCESSED.png',
#  'pipeline_outputs/data/validation/13494_PROCESSED.png',
#  'pipeline_outputs/data/validation/15308_PROCESSED.png',
#  'pipeline_outputs/data/validation/13250_PROCESSED.png',
#  'pipeline_outputs/data/validation/15421_PROCESSED.png',
#  'pipeline_outputs/data/validation/10416_PROCESSED.png',
#  'pipeline_outputs/data/validation/10546_PROCESSED.png',
#  'pipeline_outputs/data/validation/14338_PROCESSED.png',
#  'pipeline_outputs/data/validation/10401_PROCESSED.png',
#  'pipeline_outputs/data/validation/12645_PROCESSED.png',
#  'pipeline_outputs/data/validation/14385_PROCESSED.png',
#  'pipeline_outputs/data/validation/10983_PROCESSED.png',
#  'pipeline_outputs/data/validation/15566_PROCESSED.png',
#  'pipeline_outputs/data/validation/11919_PROCESSED.png',
#  'pipeline_outputs/data/validation/11083_PROCESSED.png',
#  'pipeline_outputs/data/validation/12146_PROCESSED.png',
#  'pipeline_outputs/data/validation/9748_PROCESSED.png',
#  'pipeline_outputs/data/validation/11398_PROCESSED.png',
#  'pipeline_outputs/data/validation/11325_PROCESSED.png',
#  'pipeline_outputs/data/validation/13380_PROCESSED.png',
#  'pipeline_outputs/data/validation/13855_PROCESSED.png',
#  'pipeline_outputs/data/validation/13905_PROCESSED.png',
#  'pipeline_outputs/data/validation/15017_PROCESSED.png',
#  'pipeline_outputs/data/validation/12872_PROCESSED.png',
#  'pipeline_outputs/data/validation/14545_PROCESSED.png',
#  'pipeline_outputs/data/validation/10167_PROCESSED.png',
#  'pipeline_outputs/data/validation/12865_PROCESSED.png',
#  'pipeline_outputs/data/validation/11739_PROCESSED.png',
#  'pipeline_outputs/data/validation/15000_PROCESSED.png',
#  'pipeline_outputs/data/validation/11140_PROCESSED.png',
#  'pipeline_outputs/data/validation/11335_PROCESSED.png',
#  'pipeline_outputs/data/validation/11039_PROCESSED.png',
#  'pipeline_outputs/data/validation/10667_PROCESSED.png',
#  'pipeline_outputs/data/validation/12792_PROCESSED.png',
#  'pipeline_outputs/data/validation/10255_PROCESSED.png',
#  'pipeline_outputs/data/validation/12785_PROCESSED.png',
#  'pipeline_outputs/data/validation/14660_PROCESSED.png',
#  'pipeline_outputs/data/validation/14730_PROCESSED.png',
#  'pipeline_outputs/data/validation/15083_PROCESSED.png',
#  'pipeline_outputs/data/validation/11657_PROCESSED.png',
#  'pipeline_outputs/data/validation/11272_PROCESSED.png',
#  'pipeline_outputs/data/validation/13387_PROCESSED.png',
#  'pipeline_outputs/data/validation/10027_PROCESSED.png',
#  'pipeline_outputs/data/validation/14709_PROCESSED.png',
#  'pipeline_outputs/data/validation/10649_PROCESSED.png',
#  'pipeline_outputs/data/validation/14020_PROCESSED.png',
#  'pipeline_outputs/data/validation/15572_PROCESSED.png',
#  'pipeline_outputs/data/validation/11017_PROCESSED.png',
#  'pipeline_outputs/data/validation/13417_PROCESSED.png',
#  'pipeline_outputs/data/validation/14734_PROCESSED.png',
#  'pipeline_outputs/data/validation/14673_PROCESSED.png',
#  'pipeline_outputs/data/validation/14306_PROCESSED.png',
#  'pipeline_outputs/data/validation/13722_PROCESSED.png',
#  'pipeline_outputs/data/validation/13911_PROCESSED.png',
#  'pipeline_outputs/data/validation/10268_PROCESSED.png',
#  'pipeline_outputs/data/validation/10034_PROCESSED.png',
#  'pipeline_outputs/data/validation/10541_PROCESSED.png',
#  'pipeline_outputs/data/validation/12086_PROCESSED.png',
#  'pipeline_outputs/data/validation/10173_PROCESSED.png',
#  'pipeline_outputs/data/validation/10984_PROCESSED.png',
#  'pipeline_outputs/data/validation/15248_PROCESSED.png',
#  'pipeline_outputs/data/validation/15342_PROCESSED.png',
#  'pipeline_outputs/data/validation/10129_PROCESSED.png',
#  'pipeline_outputs/data/validation/9782_PROCESSED.png',
#  'pipeline_outputs/data/validation/12748_PROCESSED.png',
#  'pipeline_outputs/data/validation/14740_PROCESSED.png',
#  'pipeline_outputs/data/validation/14610_PROCESSED.png',
#  'pipeline_outputs/data/validation/12297_PROCESSED.png',
#  'pipeline_outputs/data/validation/12076_PROCESSED.png',
#  'pipeline_outputs/data/validation/14889_PROCESSED.png',
#  'pipeline_outputs/data/validation/14372_PROCESSED.png',
#  'pipeline_outputs/data/validation/15205_PROCESSED.png',
#  'pipeline_outputs/data/validation/11067_PROCESSED.png',
#  'pipeline_outputs/data/validation/15077_PROCESSED.png',
#  'pipeline_outputs/data/validation/12942_PROCESSED.png',
#  'pipeline_outputs/data/validation/12590_PROCESSED.png',
#  'pipeline_outputs/data/validation/13822_PROCESSED.png',
#  'pipeline_outputs/data/validation/13289_PROCESSED.png',
#  'pipeline_outputs/data/validation/11759_PROCESSED.png',
#  'pipeline_outputs/data/validation/15281_PROCESSED.png',
#  'pipeline_outputs/data/validation/15478_PROCESSED.png',
#  'pipeline_outputs/data/validation/11468_PROCESSED.png',
#  'pipeline_outputs/data/validation/12135_PROCESSED.png',
#  'pipeline_outputs/data/validation/12510_PROCESSED.png',
#  'pipeline_outputs/data/validation/14977_PROCESSED.png',
#  'pipeline_outputs/data/validation/9858_PROCESSED.png',
#  'pipeline_outputs/data/validation/11592_PROCESSED.png',
#  'pipeline_outputs/data/validation/13745_PROCESSED.png',
#  'pipeline_outputs/data/validation/11228_PROCESSED.png',
#  'pipeline_outputs/data/validation/12801_PROCESSED.png',
#  'pipeline_outputs/data/validation/10461_PROCESSED.png',
#  'pipeline_outputs/data/validation/10218_PROCESSED.png',
#  'pipeline_outputs/data/validation/15456_PROCESSED.png',
#  'pipeline_outputs/data/validation/13602_PROCESSED.png',
#  'pipeline_outputs/data/validation/13377_PROCESSED.png',
#  'pipeline_outputs/data/validation/11282_PROCESSED.png']

# %%
for file in file_paths:
    filePathNew = file.split('/')[1:]
    filePathNew[-1] = filePathNew[-1].split('_')[0]
    filePathNew = '/'.join(filePathNew)
    
    x_ray = imread(file)
    # ---------------------------------------------------------

    x_ray = np.int64(x_ray)
    x_ray = x_ray.reshape((-1,1))

    k_m = cluster.KMeans(n_clusters=5, n_init=4)
    k_m.fit(x_ray)

    values = np.int64(k_m.cluster_centers_.squeeze())
    labels = np.int64(k_m.labels_)

    img_segm = np.choose(labels, values)
    img_segm.shape = (256, 256, 1)

    pix_val = 0.0
    for value in (np.unique(img_segm)):
        img_segm = np.where(img_segm == value, pix_val, img_segm)
        pix_val += 0.25
        
#     print(np.unique(img_segm))
#     imshow(img_segm, cmap=plt.cm.gray)

    io.imsave('kmeans_segm/' + filePathNew + '_KMEANS.png', img_segm)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
name = './output_training/1377_PROCESSED.png'

name = name.split('/')[-1].split('_')[0]
name
# Out:
# '1377'
